# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 叱咤風雲, ID: 11181
# Movie: 馬德里金庫盜數90分鐘, ID: 11184
# Movie: 偷畫男孩, ID: 11172
# Movie: 李希特舒眠曲, ID: 11170
# Movie: 蠢蛋告別式, ID: 11166
# Movie: 我在時間盡頭等你, ID: 11164
# Movie: 靈冤而厲, ID: 11145
# Movie: 哲人王：李登輝對話篇, ID: 11144
# Movie: 冰血驚魂, ID: 11142
# Movie: 末路狂奔, ID: 11141
# Movie: 凶宅怪談, ID: 11128
# Movie: 死亡醫生的遺產, ID: 11125
# Movie: 好好拍電影, ID: 11119
# Movie: 一步一步的愛, ID: 11117
# Movie: 最美麗的歲月, ID: 11112
# Movie: 異種獵殺, ID: 11110
# Movie: 千年女優4K數位修復版, ID: 11062
# Movie: 俘虜, ID: 11146
# Movie: 少女墮落日記, ID: 11134
# Movie: 舊愛靈靈妻, ID: 11114
# Movie: 妄想代理人：後篇, ID: 11103
# Movie: 末世戰疫：鳴鳥檔案, ID: 11097
# Movie: 迷失安狄, ID: 11085
# Movie: 聖誕殺戮日, ID: 11067
# Movie: 謎宮, ID: 11039
# Movie: 破處那件小事, ID: 11029
# Movie: 空中謎航, ID: 11152
# Movie: 致命天際線, ID: 11147
# Movie: 妄想代理人：前篇, ID: 11102
# Movie: 水漾的女人, ID: 11065
# Movie: 午夜天鵝, ID: 11045
# Movie: 拆彈專家2, ID: 10986
# Movie: 杏林醫院, ID: 10781
# Movie: 靈魂急轉彎, ID: 11089
# Movie: 腿, ID: 10934
# Movie: 85年的夏天, ID: 11076
# Movie: 順其自然的日子, ID: 11066
# Movie: 神力女超人1984, ID: 10413
# Movie: 信用詐欺師JP：公主篇, ID: 11021
# Movie: 求婚好意外, ID: 10796
# Movie: 熱血合唱團, ID: 11044
# Movie: 魔物獵人, ID: 10983
# Movie: 用甜酒漱口, ID: 10895
# Movie: MISS, ID: 11036
# Movie: 尋找小魔女Doremi, ID: 11027
# Movie: 緝毒風暴, ID: 11023
# Movie: 說不出的告別, ID: 11019
# Movie: 古魯家族：新石代, ID: 10958
# Movie: 婊兄弟上路, ID: 11003
# Movie: 消失的星期三, ID: 10949
# Movie: 同學麥娜絲, ID: 10935
# Movie: 名偵探柯南：紅之校外旅行 鮮紅篇&戀紅篇, ID: 10887
# Movie: 換人殺砍砍, ID: 10933
# Movie: 愛麗絲與夢幻島, ID: 11018
# Movie: 孤味, ID: 10477
# Movie: 女巫們, ID: 10976
# Movie: 入魔, ID: 10989
# Movie: 鬼滅之刃劇場版 無限列車篇, ID: 10816
# Movie: 親愛的房客, ID: 10707
# Movie: 地下弒的秘密, ID: 10984
# Movie: 看不見的目擊者, ID: 10946
# Movie: 無聲, ID: 10926
# Movie: 倒數反擊, ID: 10906
# Movie: 阿公當家, ID: 10914
# Movie: 刻在你心底的名字, ID: 10902
# Movie: 急先鋒, ID: 10443
# Movie: 消失的情人節, ID: 10870
# Movie: 麥路人, ID: 10900
# Movie: 密弒直播, ID: 10888
# Movie: 美麗佳人歐蘭朵, ID: 10876
# Movie: TENET天能, ID: 10433
# Movie: 巴亞拉魔幻冒險, ID: 10851
# Movie: 角落小夥伴電影版：魔法繪本裡的新朋友, ID: 10647
# Movie: 1917, ID: 10189
# Movie: 海上花, ID: 10376
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 消失打看, ID: 3819
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 11141

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
#print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17
# 放映地區: 屏東, 代號(area_id): 14
# 放映地區: 宜蘭, 代號(area_id): 11
# 放映地區: 金門, 代號(area_id): 24
# 放映地區: 澎湖, 代號(area_id): 23

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 一月 17
# 一月 18
# 一月 19
# 一月 20
# 一月 21

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2021-01-18"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="pc-movie-schedule-form">
#    <div class="area_timebox">
#     <div class="area_title">
#      台北市
#     </div>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北美麗華大直影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=32" data-theater_url="http://www.miramarcinemas.tw/" id="theater_id_32">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=32">
#        台北美麗華大直影城
#       </a>
#       <span>
#        02-85022208
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ab24ff5bb7d24b43b8d9a05b6f8df96d" data-movie_date="01.18" data-movie_time="09:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="090b9216dbfe45dcade46328c7dd630a" data-time="1610932200" id="74817051" name="schedule_list" type="radio" value="2021-01-18 09:10:00"/>
#        <label class="select" for="74817051">
#         09:10
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ab24ff5bb7d24b43b8d9a05b6f8df96d" data-movie_date="01.18" data-movie_time="14:30" data-movie_title="末路狂奔" data-movie_type="數位" data-session="6ffc61babc4b4c9e8fbf5cf06f281fb0" data-time="1610951400" id="74817052" name="schedule_list" type="radio" value="2021-01-18 14:30:00"/>
#        <label class="select" for="74817052">
#         14:30
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ab24ff5bb7d24b43b8d9a05b6f8df96d" data-movie_date="01.18" data-movie_time="20:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="5e63d3b9ef67430aa8b13637cf79fca7" data-time="1610971800" id="74817053" name="schedule_list" type="radio" value="2021-01-18 20:10:00"/>
#        <label class="select" for="74817053">
#         20:10
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ab24ff5bb7d24b43b8d9a05b6f8df96d" data-movie_date="01.18" data-movie_time="21:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="e64fbabc9ab646a38521fcd171935bff" data-time="1610975400" id="74817054" name="schedule_list" type="radio" value="2021-01-18 21:10:00"/>
#        <label class="select" for="74817054">
#         21:10
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北in89豪華數位影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=36" data-theater_url="http://www.in89.com.tw/website_module.php?website_module_classify_sn=39" id="theater_id_36">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=36">
#        台北in89豪華數位影城
#       </a>
#       <span>
#        02-23315077
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="5b1944102f3149e08198c259ac24d7f3" data-movie_date="01.18" data-movie_time="09:50" data-movie_title="末路狂奔" data-movie_type="數位" data-session="7e0eb9066e8746eebcfcf957fe004884" data-time="1610934600" id="74817267" name="schedule_list" type="radio" value="2021-01-18 09:50:00"/>
#        <label class="select" for="74817267">
#         09:50
#        </label>
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="5b1944102f3149e08198c259ac24d7f3" data-movie_date="01.18" data-movie_time="14:00" data-movie_title="末路狂奔" data-movie_type="數位" data-session="683fb6e04b574aad80f8386e0d80e3a8" data-time="1610949600" id="74817268" name="schedule_list" type="radio" value="2021-01-18 14:00:00"/>
#        <label class="select" for="74817268">
#         14:00
#        </label>
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="5b1944102f3149e08198c259ac24d7f3" data-movie_date="01.18" data-movie_time="18:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="36a0e101fe07432d98021614d300d67e" data-time="1610964600" id="74817269" name="schedule_list" type="radio" value="2021-01-18 18:10:00"/>
#        <label class="select" for="74817269">
#         18:10
#        </label>
#        <input class="gabtn" data-cinema="e9c365f27f4e11e494ae8b4ddf78b93a" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="5b1944102f3149e08198c259ac24d7f3" data-movie_date="01.18" data-movie_time="21:25" data-movie_title="末路狂奔" data-movie_type="數位" data-session="e30e323745a64dbe8180a6d405dd0ca3" data-time="1610976300" id="74828460" name="schedule_list" type="radio" value="2021-01-18 21:25:00"/>
#        <label class="select" for="74828460">
#         21:25
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">
#        台北信義威秀影城
#       </a>
#       <span>
#        02-87805566
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="773602d28b644c2998fa284c501c63fa" data-movie_date="01.18" data-movie_time="09:55" data-movie_title="末路狂奔" data-movie_type="數位" data-session="5618408e538a43048aff83b0700cff07" data-time="1610934900" id="74817493" name="schedule_list" type="radio" value="2021-01-18 09:55:00"/>
#        <label class="select" for="74817493">
#         09:55
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="773602d28b644c2998fa284c501c63fa" data-movie_date="01.18" data-movie_time="14:25" data-movie_title="末路狂奔" data-movie_type="數位" data-session="35718d2bef5a4a03b162885d275bd583" data-time="1610951100" id="74817494" name="schedule_list" type="radio" value="2021-01-18 14:25:00"/>
#        <label class="select" for="74817494">
#         14:25
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="773602d28b644c2998fa284c501c63fa" data-movie_date="01.18" data-movie_time="19:00" data-movie_title="末路狂奔" data-movie_type="數位" data-session="8b10ea50cadb413e842a98f18a3823ea" data-time="1610967600" id="74817495" name="schedule_list" type="radio" value="2021-01-18 19:00:00"/>
#        <label class="select" for="74817495">
#         19:00
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="773602d28b644c2998fa284c501c63fa" data-movie_date="01.18" data-movie_time="23:25" data-movie_title="末路狂奔" data-movie_type="數位" data-session="30264f1515714403a9f3814b8621affc" data-time="1610983500" id="74817496" name="schedule_list" type="radio" value="2021-01-18 23:25:00"/>
#        <label class="select" for="74817496">
#         23:25
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="京站威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=118" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_118">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=118">
#        京站威秀影城
#       </a>
#       <span>
#        02-25525511
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="0aad2a4f7eb54203aa8543a674e9f6f8" data-movie_date="01.18" data-movie_time="11:50" data-movie_title="末路狂奔" data-movie_type="數位" data-session="63f00c0343db4c4ca173fc4d8a8a370a" data-time="1610941800" id="74816586" name="schedule_list" type="radio" value="2021-01-18 11:50:00"/>
#        <label class="select" for="74816586">
#         11:50
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="0aad2a4f7eb54203aa8543a674e9f6f8" data-movie_date="01.18" data-movie_time="16:50" data-movie_title="末路狂奔" data-movie_type="數位" data-session="b047436485a541569064aaa515330436" data-time="1610959800" id="74816587" name="schedule_list" type="radio" value="2021-01-18 16:50:00"/>
#        <label class="select" for="74816587">
#         16:50
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="0aad2a4f7eb54203aa8543a674e9f6f8" data-movie_date="01.18" data-movie_time="22:20" data-movie_title="末路狂奔" data-movie_type="數位" data-session="c0c7ffed445645c493fdbb364749948e" data-time="1610979600" id="74816588" name="schedule_list" type="radio" value="2021-01-18 22:20:00"/>
#        <label class="select" for="74816588">
#         22:20
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="梅花數位影院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=126" data-theater_url="" id="theater_id_126">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=126">
#        梅花數位影院
#       </a>
#       <span>
#        02-27326968
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="b020ba50fbc811e58858f2128151146f" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="392b7f3db3bd4c5dad6ce3245e1a20b8" data-movie_date="01.18" data-movie_time="12:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="d04b5344713c46169a80f970f419e5e1" data-time="1610943000" id="74806469" name="schedule_list" type="radio" value="2021-01-18 12:10:00"/>
#        <label class="select" for="74806469">
#         12:10
#        </label>
#        <input class="gabtn" data-cinema="b020ba50fbc811e58858f2128151146f" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="392b7f3db3bd4c5dad6ce3245e1a20b8" data-movie_date="01.18" data-movie_time="14:10" data-movie_title="末路狂奔" data-movie_type="數位" data-session="619825d81e0244caad5c8c6cc0152aa1" data-time="1610950200" id="74806470" name="schedule_list" type="radio" value="2021-01-18 14:10:00"/>
#        <label class="select" for="74806470">
#         14:10
#        </label>
#        <input class="gabtn" data-cinema="b020ba50fbc811e58858f2128151146f" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="392b7f3db3bd4c5dad6ce3245e1a20b8" data-movie_date="01.18" data-movie_time="18:30" data-movie_title="末路狂奔" data-movie_type="數位" data-session="46beb0eaf5204e1da1aeb922201fff62" data-time="1610965800" id="74806471" name="schedule_list" type="radio" value="2021-01-18 18:30:00"/>
#        <label class="select" for="74806471">
#         18:30
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">
#        喜樂時代影城南港店
#       </a>
#       <span>
#        02-27888185
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="13:00" data-movie_title="末路狂奔" data-movie_type="數位" data-session="d78d9b1b811a41d291999275ee98a0a7" data-time="1610946000" id="74821591" name="schedule_list" type="radio" value="2021-01-18 13:00:00"/>
#        <label class="select" for="74821591">
#         13:00
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="14:55" data-movie_title="末路狂奔" data-movie_type="數位" data-session="f91aabd7cdbb4edfa550cdba3d92a60b" data-time="1610952900" id="74821592" name="schedule_list" type="radio" value="2021-01-18 14:55:00"/>
#        <label class="select" for="74821592">
#         14:55
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="16:25" data-movie_title="末路狂奔" data-movie_type="數位" data-session="4dbe6229b75844f9b74dc3d81ab09a12" data-time="1610958300" id="74821593" name="schedule_list" type="radio" value="2021-01-18 16:25:00"/>
#        <label class="select" for="74821593">
#         16:25
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="18:50" data-movie_title="末路狂奔" data-movie_type="數位" data-session="e2bcf1751d6f45b7a533ed062ceeb744" data-time="1610967000" id="74821594" name="schedule_list" type="radio" value="2021-01-18 18:50:00"/>
#        <label class="select" for="74821594">
#         18:50
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="20:45" data-movie_title="末路狂奔" data-movie_type="數位" data-session="de5aae24f34b47c781afe9a176ec0f43" data-time="1610973900" id="74821595" name="schedule_list" type="radio" value="2021-01-18 20:45:00"/>
#        <label class="select" for="74821595">
#         20:45
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="ae1749472316441b8266b8de1e7b1ee3" data-movie_date="01.18" data-movie_time="22:40" data-movie_title="末路狂奔" data-movie_type="數位" data-session="9ea6ace820df4522abfa3cdbaa3540cd" data-time="1610980800" id="74821596" name="schedule_list" type="radio" value="2021-01-18 22:40:00"/>
#        <label class="select" for="74821596">
#         22:40
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="MUVIE CINEMAS台北松仁威秀" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=254" data-theater_url="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23" id="theater_id_254">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=254">
#        MUVIE CINEMAS台北松仁威秀
#       </a>
#       <span>
#        (02)8780-0800
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="c15235a8715c451a9d9d0681fdc605fe" data-movie_date="01.18" data-movie_time="10:05" data-movie_title="末路狂奔" data-movie_type="數位" data-session="71f007cf9e604145b8d71531a33d7111" data-time="1610935500" id="74812997" name="schedule_list" type="radio" value="2021-01-18 10:05:00"/>
#        <label class="select" for="74812997">
#         10:05
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="c15235a8715c451a9d9d0681fdc605fe" data-movie_date="01.18" data-movie_time="12:15" data-movie_title="末路狂奔" data-movie_type="數位" data-session="e9c4a12c31a445489bde73b91183c944" data-time="1610943300" id="74812998" name="schedule_list" type="radio" value="2021-01-18 12:15:00"/>
#        <label class="select" for="74812998">
#         12:15
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="c15235a8715c451a9d9d0681fdc605fe" data-movie_date="01.18" data-movie_time="18:50" data-movie_title="末路狂奔" data-movie_type="數位" data-session="c0c9ac0294b34ff3bbadd7028f39dc2d" data-time="1610967000" id="74812999" name="schedule_list" type="radio" value="2021-01-18 18:50:00"/>
#        <label class="select" for="74812999">
#         18:50
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1610899200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '末路狂奔']" data-movie="c15235a8715c451a9d9d0681fdc605fe" data-movie_date="01.18" data-movie_time="22:20" data-movie_title="末路狂奔" data-movie_type="數位" data-session="a64064b2ef8240e38f584f2417014618" data-time="1610979600" id="74813000" name="schedule_list" type="radio" value="2021-01-18 22:20:00"/>
#        <label class="select" for="74813000">
#         22:20
#        </label>
#       </div>
#      </li>
#     </ul>
#    </div>
#    <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop">
#     </div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#      <form action="https://movies.yahoo.com.tw/ticket/ezding_ticket" id="form_schedule" method="get" target="_blank">
#       <div class="ezding_ticket_value">
#        <input name="movie_id" type="hidden" value=""/>
#        <input name="cinema_id" type="hidden" value=""/>
#        <input name="session_id" type="hidden" value=""/>
#        <input name="date" type="hidden" value=""/>
#        <input name="time" type="hidden" value=""/>
#        <input name="campaign_code" type="hidden" value="yahoopc"/>
#       </div>
#       <ul class="top_infos">
#        <li>
#         <p>
#          片名
#         </p>
#         <h3 id="top_infos_movie">
#         </h3>
#        </li>
#        <li>
#         <p>
#          影城
#         </p>
#         <h3 id="top_infos_theater">
#         </h3>
#        </li>
#        <li>
#         <p>
#          日期
#         </p>
#         <h3 id="top_infos_date">
#         </h3>
#        </li>
#        <li>
#         <p>
#          版本
#         </p>
#         <h3 id="top_infos_movie_type">
#         </h3>
#        </li>
#        <li>
#         <p>
#          時間
#         </p>
#         <h3 id="top_infos_time">
#         </h3>
#        </li>
#       </ul>
#       <div class="booking_seats">
#        <a class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']" href="#">
#         全部電影場次
#        </a>
#        <a class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <p class="no_theater_url" id="no_theater_url">
#         無提供官網訂票
#        </p>
#        <p class="booking_number" id="booking_number">
#         人數
#        </p>
#        <div class="booking_seat_group jq_booking_seat_group">
#         <input id="seat_1" name="tickets" type="radio" value="1"/>
#         <label for="seat_1">
#          1
#         </label>
#         <input checked="" id="seat_2" name="tickets" type="radio" value="2"/>
#         <label for="seat_2">
#          2
#         </label>
#         <input id="seat_3" name="tickets" type="radio" value="3"/>
#         <label for="seat_3">
#          3
#         </label>
#         <input id="seat_4" name="tickets" type="radio" value="4"/>
#         <label for="seat_4">
#          4
#         </label>
#         <input id="seat_5" name="tickets" type="radio" value="5"/>
#         <label for="seat_5">
#          5
#         </label>
#         <input id="seat_6" name="tickets" type="radio" value="6"/>
#         <label for="seat_6">
#          6
#         </label>
#        </div>
#        <button class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']" type="submit">
#         選位
#        </button>
#        <a class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <button class="action_btn close jq_close_booking_btn" type="button">
#         關閉
#        </button>
#       </div>
#      </form>
#      <!-- 無官網訂票區塊 -->
#      <div class="no_theater_section">
#       <p>
#        無提供官網訂票
#       </p>
#       <button class="action_btn close jq_close_booking_btn" type="button">
#        關閉
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
for d in html:
    print("電影院: ", d.a.string)
    print("放映類型: ", d.find("input")["data-movie_type"])
    for time in d.find_all("input"):
        print(time["value"])
# Out:
# 電影院:  台北美麗華大直影城
# 放映類型:  數位
# 2021-01-18 09:10:00
# 2021-01-18 14:30:00
# 2021-01-18 20:10:00
# 2021-01-18 21:10:00
# 電影院:  台北in89豪華數位影城
# 放映類型:  數位
# 2021-01-18 09:50:00
# 2021-01-18 14:00:00
# 2021-01-18 18:10:00
# 2021-01-18 21:25:00
# 電影院:  台北信義威秀影城
# 放映類型:  數位
# 2021-01-18 09:55:00
# 2021-01-18 14:25:00
# 2021-01-18 19:00:00
# 2021-01-18 23:25:00
# 電影院:  京站威秀影城
# 放映類型:  數位
# 2021-01-18 11:50:00
# 2021-01-18 16:50:00
# 2021-01-18 22:20:00
# 電影院:  梅花數位影院
# 放映類型:  數位
# 2021-01-18 12:10:00
# 2021-01-18 14:10:00
# 2021-01-18 18:30:00
# 電影院:  喜樂時代影城南港店
# 放映類型:  數位
# 2021-01-18 13:00:00
# 2021-01-18 14:55:00
# 2021-01-18 16:25:00
# 2021-01-18 18:50:00
# 2021-01-18 20:45:00
# 2021-01-18 22:40:00
# 電影院:  MUVIE CINEMAS台北松仁威秀
# 放映類型:  數位
# 2021-01-18 10:05:00
# 2021-01-18 12:15:00
# 2021-01-18 18:50:00
# 2021-01-18 22:20:00
