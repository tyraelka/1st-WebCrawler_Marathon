# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
reponse = r.text

data = json.loads(reponse)
data
# Out:
# [{'id': 235162812,
#   'title': '貓咪尾巴骨折了',
#   'excerpt': '更/，謝謝大家的回覆（認真推薦醫生醫院的各位真的很謝謝你們🥰🥰給了我們好多條除了斷尾的選擇🥺），我們決定先觀察個兩三天再去問問看大家提供的醫生，下面是我們家寶貝的照片️，我家的貓咪不知道做了什麼他的尾巴',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-01-13T03:34:59.281Z',
#   'updatedAt': '2021-01-13T13:31:03.421Z',
#   'commentCount': 141,
#   'likeCount': 1568,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '骨折', '尾巴', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '胖咘最可愛',
#   'department': 'delphy',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '40e2d438-18dc-4cad-b549-0395ad4f8921',
#     'url': 'https://i.imgur.com/avLFc1ol.jpg',
#     'normalizedUrl': 'https://i.imgur.com/avLFc1ol.jpg',
#     'thumbnail': 'https://i.imgur.com/avLFc1ol.jpg',
# ...

# %%
len(data)
# Out:
# 30

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

'''
Your Code
'''

# API回傳資料筆數
print("Dcard API一次回傳資料共%s筆" %str(len(data)))

# 資料欄位
keys = []
for i in data[0].keys():
    keys.append(i)
keys
# Out:
# Dcard API一次回傳資料共30筆
# ['id',
#  'title',
#  'excerpt',
#  'anonymousSchool',
#  'anonymousDepartment',
#  'pinned',
#  'forumId',
#  'replyId',
#  'createdAt',
#  'updatedAt',
#  'commentCount',
#  'likeCount',
#  'withNickname',
#  'tags',
#  'topics',
#  'meta',
#  'forumName',
#  'forumAlias',
#  'nsfw',
#  'gender',
#  'school',
#  'department',
#  'replyTitle',
#  'mediaMeta',
#  'reactions',
#  'hidden',
#  'customStyle',
#  'isSuspiciousAccount',
#  'isModerator',
#  'layout',
#  'spoilerAlert',
#  'withImages',
#  'withVideos',
#  'media',
#  'reportReasonText',
#  'excerptComments',
#  'postAvatar',
#  'verifiedBadge']

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %%
貼文

# %%
Titles = []
Time=[]
Like=[]
Comment=[]

for d in data:
    Titles.append(d["title"])
    Time.append(d["createdAt"])
    Like.append(d["likeCount"])
    Comment.append(d["commentCount"])
dict_ = {"Title": Titles, "Time": Time, "LikeCount": Like, "CommentCount": Comment}

dict_
# Out:
# {'Title': ['貓咪尾巴骨折了',
#   '請在三秒內指認出貓頭在哪邊',
#   '貓咪的奇怪趴姿🤨',
#   '你以為自己是人嗎臭貓',
#   '第七天...',
#   '米克斯柴犬',
#   '貓咪身上的花樣',
#   '他是不是想殺我？',
#   '可憐流浪貓雪中敲窗求救，獲好心人收養',
#   '注意！不小心就被捆住...',
#   '有主人的小黑 卻從來沒有得到過溫暖',
#   '#分享 5款美美的貓碗評比 (文長 圖多)',
#   '#分享 意外發現蝸牛萌寵',
#   '貓咪尿不出來',
#   '偷看人上廁所的貓',
#   '貓吸了太陽之後...',
#   '像隻豬一樣',
#   '向「錢」突刺～～刺～',
#   '你有看過會玩撲克牌心臟病的天竺鼠嗎？🤣又逗又萌～心臟被爆擊❤️',
#   '你雖然是臘腸也不能這樣啊🤣',
#   '是送養還是繼續養',
#   '你們兩個不能同時看鏡頭嗎？',
#   '內有可愛貓，快點進來看❤️台灣防止虐待動物協會 工作機會～',
#   '帶兔兔坐飛機',
#   '阿狗的各種奇妙裝扮🤣',
#   '協尋斑鳩',
#   '寵物gps追蹤器',
#   '猜猜貓貓在哪裡',
#   '半夜3點😂',
#   '遛狗'],
#  'Time': ['2021-01-13T03:34:59.281Z',
#   '2021-01-13T06:54:49.465Z',
#   '2021-01-13T04:40:43.997Z',
#   '2021-01-14T03:44:54.338Z',
#   '2021-01-14T03:18:07.595Z',
#   '2021-01-13T15:47:29.124Z',
#   '2021-01-13T09:53:35.006Z',
#   '2021-01-14T09:27:29.710Z',
#   '2021-01-14T05:01:07.813Z',
#   '2021-01-14T04:50:52.422Z',
#   '2021-01-13T17:28:13.550Z',
#   '2021-01-14T06:29:19.983Z',
#   '2021-01-13T15:03:02.284Z',
# ...

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
# Out:
# '\nYour Code\n'

# %%
# 非熱門文章
r_np = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
data_np = json.loads(r_np.text)
data_np
# Out:
# [{'id': 235172548,
#   'title': '分享一下我的貓變成多啦A夢了',
#   'excerpt': '是不是會有百寶袋呀？有興趣追蹤：每天看貓每天開心',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2021-01-14T15:36:48.468Z',
#   'updatedAt': '2021-01-14T15:36:48.468Z',
#   'commentCount': 0,
#   'likeCount': 0,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '可愛', '領養代替購買', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'Mz',
#   'department': 'axt.52',
#   'replyTitle': None,
#   'reportReason': '',
#   'mediaMeta': [{'id': '9b94d498-a885-4eec-8a4a-d5bc65cad4a1',
#     'url': 'https://megapx-assets.dcard.tw/images/89e20e5f-71c5-41ff-b3e6-298ad60264b5/160.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/89e20e5f-71c5-41ff-b3e6-298ad60264b5/160.jpeg',
# ...

# %%
import numpy as np

Comment_np = []
Like_np = []

for d in data_np:
    Comment_np.append(d["commentCount"])
    Like_np.append(d["likeCount"])

print("熱門文章平均留言人數:%.1f人, 非熱門文章平均留言人數:%.1f人" %
      ((np.mean(Comment)), (np.mean(Comment_np))))
print("熱門文章平均按讚人數:%.1f人, 非熱門文章平均按讚人數:%.1f人" %
      ((np.mean(Like)), (np.mean(Like_np))))
# Out:
# 熱門文章平均留言人數:13.6人, 非熱門文章平均留言人數:3.7人
# 熱門文章平均按讚人數:147.4人, 非熱門文章平均按讚人數:33.9人
