# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %% [markdown]
# 以Dcard網頁為目標進行比較

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = "https://www.dcard.tw/f"

resp = requests.get(url)
soup = BeautifulSoup(resp.text)
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]--><!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]--><!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Attention Required! | Cloudflare</title>
# <meta id="captcha-bypass" name="captcha-bypass"/>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" type="text/css" media="screen,projection" /><![endif]-->
# <style type="text/css">body{margin:0;padding:0}</style>
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
# <script type="text/javascript">
#     //<![CDATA[
#     (function(){
#       window._cf_chl_opt={
#         cvId: "1",
#         cType: "interactive",
#         cNounce: "41576",
#         cRay: "6126873e29e1f08d",
#         cHash: "b64707020670f0a",
#         cFPWv: "b",
#         cRq: {
#           ru: "aHR0cHM6Ly93d3cuZGNhcmQudHcvZg==",
#           ra: "cHl0aG9uLXJlcXVlc3RzLzIuMjQuMA==",
#           rm: "R0VU",
#           d: "...",
#           t: "MTYxMDc4NjM5MC43NDkwMDA=",
#           m: "9XaXMfYMnhRGw27adsSGi8FNHUxE0IYG2xhGTpJDlWY=",
#           i1: "pgdzVoi59G3qJfGaYpG/mg==",
#           i2: "0CwdPwKOtTvackiCCuLhLg==",
#           uh: "6AZv5/FBI8bCgQ115dPTZ5RPLfsmzGOqXp7x0al4Jbc=",
#           hh: "zRzOAigP6xcxnKf5snryJLVJgndZSARNtnIbgQqzl/Q=",
#         }
#       }
#       window._cf_chl_enter = function(){window._cf_chl_opt.p=1};
#       var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         var cookieSupportInfix=cookiesEnabled?'/nocookie':'/cookie';
#         var cpo = document.createElement('script');
#         cpo.type = 'text/javascript';
#         cpo.src = "/cdn-cgi/challenge-platform/h/b/orchestrate/captcha/v1";
#         var done = false;
#         cpo.onload = cpo.onreadystatechange = function() {
#           if (!done && (!this.readyState || this.readyState === "loaded" || this.readyState === "complete")) {
#             done = true;
#             cpo.onload = cpo.onreadystatechange = null;
#             window._cf_chl_enter()
#           }
#         };
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#       }, false);
#     })();
#     //]]>
#   </script>
# <style type="text/css">
#   #cf-wrapper #spinner {width:69px; margin:  auto;}
#   #cf-wrapper #cf-please-wait{text-align:center}
#   .attribution {margin-top: 32px;}
#   .bubbles { background-color: #f58220; width:20px; height: 20px; margin:2px; border-radius:100%; display:inline-block; }
#   #cf-wrapper #challenge-form { padding-top:25px; padding-bottom:25px; }
#   #cf-hcaptcha-container { text-align:center;}
#   #cf-hcaptcha-container iframe { display: inline-block;}
#   @keyframes fader     { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-wrapper #cf-bubbles { width:69px; }
#   @-webkit-keyframes fader { 0% {opacity: 0.2;} 50% {opacity: 1.0;} 100% {opacity: 0.2;} }
#   #cf-bubbles > .bubbles { animation: fader 1.6s infinite;}
#   #cf-bubbles > .bubbles:nth-child(2) { animation-delay: .2s;}
#   #cf-bubbles > .bubbles:nth-child(3) { animation-delay: .4s;}
# </style>
# </head>
# <body>
# <div id="cf-wrapper">
# <div class="cf-alert cf-alert-error cf-cookie-error" data-translate="enable_cookies" id="cookie-alert">Please enable cookies.</div>
# <div class="cf-error-details-wrapper" id="cf-error-details">
# <div class="cf-wrapper cf-header cf-error-overview">
# <h1 data-translate="challenge_headline">One more step</h1>
# <h2 class="cf-subheadline"><span data-translate="complete_sec_check">Please complete the security check to access</span> www.dcard.tw</h2>
# </div>
# <div class="cf-section cf-highlight cf-captcha-container">
# <div class="cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <div class="cf-highlight-inverse cf-form-stacked">
# <form action="/f?__cf_chl_captcha_tk__=4bd7b113085a071928ffaf43df874907310fa5b4-1610786390-0-AauyIRsvHvFqP8Xp3-SQO2TjNWBCAcAyJSldd7j84tvgIc7xICMu3pUNZ1LW125VaiWS6JVf5zmutnxCShXPKntNFryJW2ch9Fy4PAs_L2TontJkokVbA11iFYhsJE6b5Ik2vjvoRPRMO_xYFAIB-_MK_Ic8M-1oXIJ0TTwimyCBcsuIMBRtePExKZKk7ZxAfD0GemlslOLw9AzrIlPdrvUq4WlhRZ2OKynstbJGsbQBGXqDzYmt6L3TNbQ-LXBkmHaWqU5wOyvAV2y8QVKhDIyK-HAwWWeDkWgol9WnGc0oZVNJipgpA2V3zuNnPT7LNggM4yXWSg4O6VXV9K_tWZ_uT8UpZFC1De20wAqVTawEi_bddMyEUHPoANrQJyRvM0PLKquGhN_0oNuErWyuEwIwlXSUQ8KpUBfYkruj_MhMRd-9iU0SlkqXxlqvAGE9se5CTqTKtJg5LNdUoNeZXvIT6acVKPC3HCLWVJwBkKmIAE1b8SBgNi61hXskTD7feR5BnQScKGXbvKTc4rCrzbxF0DmOsws-e5eztNl3eI_cudRE-JI959W9zM8qYhIVzBz-vr7VAuV2wKs4kTDthJw" class="challenge-form interactive-form" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
# <div id="cf-please-wait">
# <div id="spinner">
# <div id="cf-bubbles">
# <div class="bubbles"></div>
# <div class="bubbles"></div>
# <div class="bubbles"></div>
# </div>
# </div>
# <p data-translate="please_wait" id="cf-spinner-please-wait">Please stand by, while we are checking your browser...</p>
# </div>
# <input name="r" type="hidden" value="06292b93cb89412d52452fed138b52fb6e0bb2f8-1610786390-0-..."/>
# <input name="cf_captcha_kind" type="hidden" value="h"/>
# <input name="vc" type="hidden" value="759363bb407ba946d9b0c9a041a3e3e0"/>
# <noscript class="cf-captcha-info" id="cf-captcha-bookmark">
# <h1 data-translate="turn_on_js" style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1>
# </noscript>
# <div class="cookie-warning" data-translate="turn_on_cookies" id="no-cookie-warning" style="display:none">
# <p data-translate="turn_on_cookies" style="color:#bd2426;">Please enable Cookies and reload the page.</p>
# </div>
# <script type="text/javascript">
#   //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#   </script>
# <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/h/transparent.gif?ray=6126873e29e1f08d')"></div>
# </form>
# </div>
# </div>
# <div class="cf-column">
# <div class="cf-screenshot-container">
# <span class="cf-no-screenshot"></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cf-section cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <h2 data-translate="why_captcha_headline">Why do I have to complete a CAPTCHA?</h2>
# <p data-translate="why_captcha_detail">Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.</p>
# </div>
# <div class="cf-column">
# <h2 data-translate="resolve_captcha_headline">What can I do to prevent this in the future?</h2>
# <p data-translate="resolve_captcha_antivirus">If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.</p>
# <p data-translate="resolve_captcha_network">If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.</p>
# </div>
# </div>
# </div>
# <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
# <p class="text-13">
# <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">6126873e29e1f08d</strong></span>
# <span class="cf-footer-separator sm:hidden">•</span>
# <span class="cf-footer-item sm:block sm:mb-1"><span>Your IP</span>: 114.45.146.1</span>
# <span class="cf-footer-separator sm:hidden">•</span>
# <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a></span>
# </p>
# </div><!-- /.error-footer -->
# </div>
# </div>
# <script type="text/javascript">
#   window._cf_translation = {};
#
#
# </script>
# </body>
# </html>

# %% [markdown]
# ## Grab + PyQuery

# %%
'''
Your Code
'''
from grab import Grab
from pyquery import PyQuery as pq

g = Grab()
resp = g.go(url)
data = pq(resp.body)
print(data)
# Out:
# <html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemtype="https://schema.org/WebSite"><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-8783abf2c964e446614d4d22e23ca2bb.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-32dfd860d03fae33428bcfcabbc07df5.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-7974ce7fd55403bdd4174737b963d694.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-8ddcd08c7f194cf623c2e405e1689557.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-f33c45592fe2c81b9f6fa9f7689e0d17.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/media/icon-72-4390490d91681428383d075d41977580.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/media/icon-76-d6563e5ba905e13955938af1697d8015.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/media/icon-114-b8fad6b9e2bc12d6516b58612539be50.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/media/icon-120-f7c73abe77f9f8500bb2ab73cce5fa43.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/media/icon-144-e29b1dfa92ae6b6288184429b165f543.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/media/icon-152-298677be6ebcf68acf1efd932b138c47.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/media/icon-180-53b4506f2ba6156616310137fa6f68a4.png"/><link rel="shortcut icon" type="image/png" href="/_next/static/media/icon-32-7974ce7fd55403bdd4174737b963d694.png"/><meta charset="utf-8"/><meta name="description" co ...
# window.dataLayer.push({'gtm.start': new Date().getTime(), event: 'gtm.js'});</script><link rel="preload" as="script" href="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M"/><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWLTW4M"/><meta name="next-head-count" content="27"/><link rel="preload" href="/_next/static/css/d1186dd04f143b42311e.css" as="style"/><link rel="stylesheet" href="/_next/static/css/d1186dd04f143b42311e.css" data-n-g=""/><link rel="preload" href="/_next/static/css/7fbedb2bf2bfe8541bc3.css" as="style"/><link rel="stylesheet" href="/_next/static/css/7fbedb2bf2bfe8541bc3.css" data-n-p=""/><noscript data-n-css=""/><link rel="preload" href="/_next/static/chunks/c8f7fe3b0e41be846d5687592cf2018ff6e22687.851eaf46538dbf2ecca4.js" as="script"/><link rel="preload" href="/_next/static/chunks/78d62a35dcc6dedda879910d5b00bd9d449f477e.2b732ea3787b71e58eaa.js" as="script"/><link rel="preload" href="/_next/static/chunks/196.f9b435f5369fdd9e1a18.js" as="script"/><link rel="preload" href="/_next/static/chunks/138.220e18cde1e6fd699652.js" as="script"/><link rel="preload" href="/_next/static/chunks/165.ba4344dfaac82023c5dd.js" as="script"/><link rel="preload" href="/_next/static/chunks/3c4859d19f00ad0f5d804de5d236492f40221cb1.24228bbc6ab39a549c83.js" as="script"/><link rel="preload" href="/_next/static/chunks/141.5f82c726d503edc26c2a.js" as="script"/><link rel="preload" href="/_next/static/chunks/912a71f9b725d3246164d5326be4edab67ea4c92.fd24b28472608478a36e.js" as="script"/><link rel="preload" href="/_next/static/chunks/ddeb8ccf10a924ccb84e738c520b209d064c92ec.61d0f5ee33aa50dd12bf.js" as="script"/><link rel="preload" href="/_next/static/chunks/07ddc8feebba80388bd103699a5e8a2319231b85.e9bfaa69fc920e0e649c.js" as="script"/><link rel="preload" href="/_next/static/chunks/133.b6b3c0805bb95af3cb1a.js" as="script"/><link rel="preload" href="/_next/static/chunks/main-2cc8e6610c933369369b.js" as="script"/><link rel="preload" href="/_next/static/chunks/webpack-090ea6da5125fa7ebcfc.js" as="script"/><link rel="preload" href="/_next/static/chunks/framework.40eb3c23eef57826c213.js" as="script"/><link rel="preload" href="/_next/static/chunks/commons.c942b2ce3a377322c0a2.js" as="script"/><link rel="preload" href="/_next/static/chunks/6de913b880945be7a7069aa709773cf9c052ae6a.8fa8b25d7a50f967cf07.js" as="script"/><link rel="preload" href="/_next/static/chunks/742b6b0b933971e3aa9e383a5f2ce65842ebdc17.33ecea471ca39ea7f67f.js" as="script"/><link rel="preload" href="/_next/static/chunks/8509ad8c4e3f3c95bea8f355b456be7dfec82476.983d75536aa1d6e4c567.js" as="script"/><link rel="preload" href="/_next/static/chunks/96bcb0de5ed6e76a4c67790685c0011e0e6df379.11c83621f8322a6a9e12.js" as="script"/><link rel="preload" href="/_next/static/chunks/8d8f93604e41c9448409bd20ff80f134733f820f.e6ed55dffdae3daacfe6.js" as="script"/><link rel="preload" href="/_next/static/chunks/570fd679dff231ba00abdd8ba3383d17007cb128.918c0d742cd53f216ccd.js" as="script"/><link rel="preload" href="/_next/static/chunks/8173fda833282a4ffd814776d2bf700fba46bc09.b7dd95f16300e538cf46.js" as="script"/><link rel="preload" href="/_next/static/chunks/1ec47ab539e042274c29e8e7b1a8a294cc9b1baa.22e2d6e2466f1251bad1.js" as="script"/><link rel="preload" href="/_next/static/chunks/5e97aff4698f43b0cfb0cacff49722e146c7e6e2.56de4a40d952a6dfd624.js" as="script"/><link rel="preload" href="/_next/static/chunks/912a71f9b725d3246164d5326be4edab67ea4c92.fd24b28472608478a36e.js" as="script"/><link rel="preload" href="/_next/static/chunks/ddeb8ccf10a924ccb84e738c520b209d064c92ec.61d0f5ee33aa50dd12bf.js" as="script"/><link rel="preload" href="/_next/static/chunks/a08e225f50511737b62ce4e8a8af765e4bc753a1.8c4aeb7b8c5053622ca2.js" as="script"/><link rel="preload" href="/_next/static/chunks/b43e2fac06b263321f6566f878bec696cd0c59a2.1a19d467a8752527c5c7.js" as="script"/><link rel="preload" href="/_next/static/chunks/pages/_app-6a778304a010bd2478ee.js" as="script"/><link rel="preload" href="/_nex ...
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .fKdOqo{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="ptn2cr-0"]{content:"fKdOqo,"}/*!sc*/
# .cKEIpH{position:relative;display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g3[id="oo2grd-0"]{content:"cKEIpH,"}/*!sc*/
# .chxbZY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;}/*!sc*/
# data-styled.g5[id="oo2grd-2"]{content:"chxbZY,"}/*!sc*/
# .bWFPRd{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-weight:400;font-size:16px;line-height:22px;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .bWFPRd::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .bWFPRd::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .bWFPRd:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .bWFPRd::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g7[id="oo2grd-4"]{content:"bWFPRd,"}/*!sc*/
# .dcclOl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .dcclOl form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g10[id="dj0ioy-0"]{content:"dcclOl,"}/*!sc*/
# .iXdXQA{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .iXdXQA::-webkit-search-cancel-button{display:none;}/*!sc*/
# .iXdXQA::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .iXdXQA::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .iXdXQA:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .iXdXQA::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g12[id="dj0ioy-2"]{content:"iXdXQA,"}/*!sc*/
# .jCPeIq{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g13[id="dj0ioy-3"]{content:"jCPeIq,"}/*!sc*/
# .cOpFyr{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g18[id="pkcmwm-0"]{content:"cOpFyr,"}/*!sc*/
# .eLDCeY{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .eLDCeY:hover{color:rgba(0,0,0,1);}/*!sc*/
# .eLDCeY::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .iDtdVP{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .iDtdVP:hover{color:rgba(0,0,0,1);}/*!sc*/
# .iDtdVP::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g19[id="pkcmwm-1"]{content:"eLDCeY,iDtdVP,"}/*!sc*/
# .eqbgYb{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g30[id="yj50et-0"]{content:"eqbgYb,"}/*!sc*/
# .RziXk{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .gjdXHA{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g31[id="yj50et-1"]{content:"RziXk,gjdXHA,"}/*!sc*/
# .duRTie{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g37[id="euk31c-0"]{content:"duRTie,"}/*!sc*/
# .ftfqQP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g38[id="euk31c-1"]{content:"ftfqQP,"}/*!sc*/
# .iDWoKc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g39[id="euk31c-2"]{content:"iDWoKc,"}/*!sc*/
# .hclFXC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .hclFXC:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g40[id="euk31c-3"]{content:"hclFXC,"}/*!sc*/
# .gGRdsy{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g41[id="euk31c-4"]{content:"gGRdsy,"}/*!sc*/
# .vigid{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .BjRiF{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g48[id="jjui6k-0"]{content:"vigid,BjRiF,"}/*!sc*/
# .kVSkOQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .kVSkOQ .ptn2cr-0{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g49[id="jjui6k-1"]{content:"kVSkOQ,"}/*!sc*/
# .kiyoDP{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g50[id="sc-1ahzbiw-0"]{content:"kiyoDP,"}/*!sc*/
# .fbQQAK{display:block;height:100%;}/*!sc*/
# data-styled.g51[id="sc-139xjgq-0"]{content:"fbQQAK,"}/*!sc*/
# .eHCUie{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g52[id="dqjqtp-0"]{content:"eHCUie,"}/*!sc*/
# .dfUEqC{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g69[id="fdq12b-0"]{content:"dfUEqC,"}/*!sc*/
# .eSgmCO .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g71[id="lhzs50-0"]{content:"eSgmCO,"}/*!sc*/
# .dORHpl{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g72[id="dz5d85-0"]{content:"dORHpl,"}/*!sc*/
# .blnnAR{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g73[id="dz5d85-1"]{content:"blnnAR,"}/*!sc*/
# .bNoSZs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g74[id="dz5d85-2"]{content:"bNoSZs,"}/*!sc*/
# .dsOiNx{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g78[id="e7vhde-0"]{content:"dsOiNx,"}/*!sc*/
# .dYKNYk{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .e7vhde-1,.dYKNYk:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .dYKNYk.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .dYKNYk.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g79[id="e7vhde-1"]{content:"dYKNYk,"}/*!sc*/
# .eKFbhf{cursor:pointer;}/*!sc*/
# .eKFbhf::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .e7vhde-2::before,.simplebar-mouse-entered .eKFbhf::before,.simplebar-dragging .eKFbhf::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .e7vhde-2::before,.simplebar-hover .eKFbhf::before,.simplebar-mouse-entered .eKFbhf::before,.simplebar-dragging .eKFbhf::before{opacity:1;}/*!sc*/
# .eKFbhf.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g80[id="e7vhde-2"]{content:"eKFbhf,"}/*!sc*/
# .cFFQgE{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g82[id="bxef95-0"]{content:"cFFQgE,"}/*!sc*/
# .kcilvM{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g83[id="bxef95-1"]{content:"kcilvM,"}/*!sc*/
# .coTKO{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g119[id="gthja3-1"]{content:"coTKO,"}/*!sc*/
# .dtGzvZ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .dtGzvZ:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g126[id="sc-11gkikh-0"]{content:"dtGzvZ,"}/*!sc*/
# .cNUDfZ{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .cNUDfZ vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g173[id="sc-1x2g0l4-0"]{content:"cNUDfZ,"}/*!sc*/
# .bSyDQU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g221[id="cgoejl-0"]{content:"bSyDQU,"}/*!sc*/
# .bXyEwB{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .bXyEwB:first-child{margin-left:0;}/*!sc*/
# data-styled.g222[id="cgoejl-1"]{content:"bXyEwB,"}/*!sc*/
# .fUVRSR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fUVRSR .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g223[id="cgoejl-2"]{content:"fUVRSR,"}/*!sc*/
# .fkFjDX{padding-left:6px;}/*!sc*/
# data-styled.g224[id="cgoejl-3"]{content:"fkFjDX,"}/*!sc*/
# .imygTk{grid-area:thumb;overflow:hidden;border-radius:4px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g240[id="sc-2rneb0-0"]{content:"imygTk,"}/*!sc*/
# .irBkMA{height:1px;}/*!sc*/
# data-styled.g279[id="sc-1ocsimk-0"]{content:"irBkMA,"}/*!sc*/
# .hjnOql{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g291[id="sc-1wisey8-0"]{content:"hjnOql,"}/*!sc*/
# .lbYuqq{position:relative;}/*!sc*/
# data-styled.g433[id="nd4ft2-0"]{content:"lbYuqq,"}/*!sc*/
# .bpvGjj{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns 0.5s;transition:grid-template-columns 0.5s;}/*!sc*/
# data-styled.g468[id="bvk29r-0"]{content:"bpvGjj,"}/*!sc*/
# .fRjRAX{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g469[id="bvk29r-1"]{content:"fRjRAX,"}/*!sc*/
# .hRYgdl{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g470[id="bvk29r-2"]{content:"hRYgdl,"}/*!sc*/
# .hZkCFF{grid-column:mainRight / end;}/*!sc*/
# data-styled.g471[id="bvk29r-3"]{content:"hZkCFF,"}/*!sc*/
# .LctwW{margin:0 12px;min-height:calc( 100vh - 68px );min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g472[id="sc-10tqbnq-0"]{content:"LctwW,"}/*!sc*/
# .kDeEqR{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g473[id="sc-10tqbnq-1"]{content:"kDeEqR,"}/*!sc*/
# .cdMDRF{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g491[id="uj732l-0"]{content:"cdMDRF,"}/*!sc*/
# .fxEWwt{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g492[id="uj732l-1"]{content:"fxEWwt,"}/*!sc*/
# .caFfpE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .caFfpE:last-child{padding-right:0;}/*!sc*/
# .caFfpE .ptn2cr-0{width:20px;height:20px;margin-right:6px;}/*!sc*/
# data-styled.g493[id="uj732l-2"]{content:"caFfpE,"}/*!sc*/
# .fbMrYq{padding-right:8px;}/*!sc*/
# data-styled.g494[id="uj732l-3"]{content:"fbMrYq,"}/*!sc*/
# .ggCrVt{position:relative;z-index:1;}/*!sc*/
# data-styled.g495[id="uj732l-4"]{content:"ggCrVt,"}/*!sc*/
# .hiaalP{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g496[id="tgn9uw-0"]{content:"hiaalP,"}/*!sc*/
# .eXUTCj{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g497[id="tgn9uw-1"]{content:"eXUTCj,"}/*!sc*/
# .cKeNdI{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g498[id="tgn9uw-2"]{content:"cKeNdI,"}/*!sc*/
# .iuyCWN{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .iuyCWN::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g499[id="tgn9uw-3"]{content:"iuyCWN,"}/*!sc*/
# .dcYnIB{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g500[id="tgn9uw-4"]{content:"dcYnIB,"}/*!sc*/
# .kbTIKe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g518[id="j38qb8-0"]{content:"kbTIKe,"}/*!sc*/
# .dhqYKf{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g519[id="j38qb8-1"]{content:"dhqYKf,"}/*!sc*/
# .eilCsu{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .eilCsu &gt;:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g529[id="vnm9ni-0"]{content:"eilCsu,"}/*!sc*/
# .cUDgJo{position:relative;}/*!sc*/
# .cUDgJo::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g532[id="m2vgdk-0"]{content:"cUDgJo,"}/*!sc*/
# .fclwmH{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g567[id="sc-1bfxmuy-0"]{content:"fclwmH,"}/*!sc*/
# .fzVywg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;position:relative;}/*!sc*/
# .fzVywg .ptn2cr-0{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g568[id="sc-1bfxmuy-1"]{content:"fzVywg,"}/*!sc*/
# .eQRUQs{border-radius:4px 4px 0 0;background-color:#fff;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g607[id="d4ydwz-0"]{content:"eQRUQs,"}/*!sc*/
# .dhzTzT{background:#fff;}/*!sc*/
# data-styled.g608[id="sc-1db29sy-0"]{content:"dhzTzT,"}/*!sc*/
# .gUBJtK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g746[id="sc-1nqrhll-0"]{content:"gUBJtK,"}/*!sc*/
# .gfdcON{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .gfdcON &gt; *{height:100%;width:100%;}/*!sc*/
# data-styled.g747[id="sc-1nqrhll-1"]{content:"gfdcON,"}/*!sc*/
# .cplviL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;}/*!sc*/
# data-styled.g749[id="sc-1iit2li-0"]{content:"cplviL,"}/*!sc*/
# .jmZfhn{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g750[id="sc-1iit2li-1"]{content:"jmZfhn,"}/*!sc*/
# .LGfcU{width:100%;z-index:1;}/*!sc*/
# data-styled.g756[id="sc-1iit2li-7"]{content:"LGfcU,"}/*!sc*/
# .qnXGt{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g758[id="sc-1kb03aj-0"]{content:"qnXGt,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 cFFQgE"><div class="dz5d85-0 dORHpl"><div class="dz5d85-1 blnnAR"><a title="Dcard" class="dqjqtp-0 eHCUie" href="/f"><img class="sc-139xjgq-0 fbQQAK" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg" alt="Dcard"/></a><div class="bxef95-1 kcilvM"><div class="dj0ioy-0 dcclOl"><form action=""><label class="oo2grd-0 cKEIpH"><div class="oo2grd-2 chxbZY"><input type="search" placeholder="搜尋" aria-label="搜尋" class="oo2grd-4 bWFPRd dj0ioy-2 iXdXQA" value=""/></div></label><button type="submit" title="搜尋" disabled="" class="dj0ioy-3 jCPeIq"><svg viewbox="0 0 28 28" class="ptn2cr-0 fKdOqo dj0ioy-7 jPEZmi" focusable="false" width="20" height="20" style="fill:#fff" role="img" aria-hidden="true"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"/></svg></button></form></div></div></div><div role="navigation" class="dz5d85-2 bNoSZs"><a class="jjui6k-0 vigid sc-1ahzbiw-0 kiyoDP" role="button" href="/signup"><span class="jjui6k-1 kVSkOQ">註冊 / 登入</span></a><div class="fdq12b-0 dfUEqC"><a class="jjui6k-0 BjRiF" title="更多" role="button"><span class="jjui6k-1 kVSkOQ"><svg viewbox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 fKdOqo"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"/><path fill="none" d="M0 0h24v24H0z"/></svg></span></a></div></div></div></div><div class="bvk29r-0 bpvGjj"><div class="bvk29r-1 fRjRAX"><div class="sc-1bfxmuy-0 fclwmH"><a href="/forum/all"><div class="sc-11gkikh-0 dtGzvZ"><div class="sc-1bfxmuy-1 fzVywg"><svg viewbox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 fKdOqo"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"/></svg></div><div class="gthja3-1 coTKO">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 dtGzvZ"><div class="sc-1bfxmuy-1 fzVywg"><svg viewbox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="ptn2cr-0 fKdOqo"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"/></svg></div><div class="gthja3-1 coTKO">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 dtGzvZ"><div class="sc-1bfxmuy-1 fzVywg"><svg xmlns="http://www.w3.org/2000/svg" viewbox="0 0 24 24" class="ptn2cr-0 fKdOqo m2vgdk-0 cUDgJo" focusable="false" width="24" height="24" style="fill:#fff" role="img" aria-hidden="true"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"/><path fill="none" d="M0 0h24v24H0z"/></svg></div><div class="gthja3-1 coTKO">好物研究室</div></div></a><div class="e7vhde-0 dsOiNx"><div class="simplebar-wrapper"><div class="simplebar-height-auto-o ...
