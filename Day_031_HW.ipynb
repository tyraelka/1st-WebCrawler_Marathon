# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.etmall.com.tw/"
info = requests.get(url)
soup = BeautifulSoup(info.text, "lxml")
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] 遠端主機已強制關閉一個現存的連線。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '遠端主機已強制關閉一個現存的連線。', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-2f74b6d03f78> in <module>
#       1 url = "https://www.etmall.com.tw/"
# ----> 2 info = requests.get(url)
#       3 soup = BeautifulSoup(info.text, "lxml")
#       4 print(soup.prettify())
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '遠端主機已強制關閉一個現存的連線。', None, 10054, None))

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36"
}

resp = requests.get(url, headers = headers)
soup2 = BeautifulSoup(resp.text, "lxml")
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="etmall://open?pgid=2" property="al:android:url"/>
#   <meta content="com.hyxen.app.etmall" property="al:android:package"/>
#   <meta content="EHS東森購物" property="al:android:app_name"/>
#   <meta content="etmall://open?pgid=2" property="al:ios:url"/>
#   <meta content="974433138" property="al:ios:app_store_id"/>
#   <meta content="EHS東森購物" property="al:ios:app_name"/>
#   <meta content="false" property="al:web:should_fallback"/>
#   <meta content="|ETMall東森購物" name="title"/>
#   <meta content="ETMall東森購物網，提供數十萬件商品超殺優惠，20間銀行最高10％回饋，舉辦限時下殺活動與登記好禮，APP首購再送您驚喜，讓您購好夠幸福！" name="description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="zh_TW" property="og:locale"/>
#   <meta content="東森購物" property="og:site_name"/>
#   <meta content="ETMall東森購物" property="og:title"/>
#   <meta content="ETMall東森購物網，提供數十萬件商品超殺優惠，20間銀行最高10％回饋，舉辦限時下殺活動與登記好禮，APP首購再送您驚喜，讓您購好夠幸福！" property="og:description"/>
#   <meta content="https://www.etmall.com.tw" property="og:url"/>
#   <meta content="http://media.etmall.com.tw/web/Image/Common/600x315-E.jpg" property="og:image"/>
#   <link href="https://www.etmall.com.tw" rel="canonical"/>
#   <link href="https://m.etmall.com.tw" media="only screen and (max-width:640px)" rel="alternate"/>
#   <link href="etmall://open?pgid=2" media="handheld" rel="alternate"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="350" property="og:image:width"/>
#   <meta content="350" property="og:image:height"/>
#   <meta content="Taiwan" name="location"/>
#   <meta content="ETMall東森購物" name="Author"/>
#   <meta content="ETMall東森購物" name="Subject"/>
#   <meta content="Tradition Chinese" name="Language"/>
#   <meta content="ETMall東森購物" name="Abstract"/>
#   <meta content="EASTERN HOME SHOPPING &amp; LEISURE CO., LTD." name="Copyright"/>
#   <meta content="ETMall東森購物" name="Designer"/>
#   <meta content="ETMall東森購物" name="Publisher"/>
#   <meta content="Global" name="Distribution"/>
#   <link href="/opensearch_etmall.xml" rel="search" title="東森購物" type="application/opensearchdescription+xml"/>
#   <link href="https://rec.scupio.com" rel="dns-prefetch"/>
#   <link href="https://www.facebook.com" rel="dns-prefetch"/>
#   <link href="https://connect.facebook.net" rel="dns-prefetch"/>
#   <link href="https://dcs.ettoday.net" rel="dns-prefetch"/>
#   <link href="//media.etmall.com.tw" rel="dns-prefetch"/>
#   <title>
#    ETMall東森購物
#   </title>
#   <link href="/Resource/Bundle/Css/Commons.css?v=5c8ca8d832b188b86d81" rel="stylesheet"/>
#   <link href="/Resource/Bundle/Css/Home.css?v=3da1bcf9fded7719e93b" rel="stylesheet"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-N8MKXWM');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script src="/Scripts/js/common/_cookie.js" type="text/javascript">
#   </script>
#   <script src="/Scripts/js/common/ENUM_COMMON.js" type="text/javascript">
#   </script>
#   <script>
#    function ehsTracking(data) {
#     try {
#         var errorMessage = data.errorMessage;
#         var oid = data.oid;
#         var tid = data.tid;
#         var type = data.type;
#         var description = data.description;
#         var option = data.option;
#         var imgUrl = '/Resource/Images/t.jpg?';
#         imgUrl += type ? 'type=' + type : '';
#         imgUrl += oid ? '&oid=' + oid : '';
#         imgUrl += tid ? '&tid=' + tid : '';
#         imgUrl += option ? '&option=' + option : '';
#         imgUrl += description ? '&description=' + description : ''
#         imgUrl += errorMessage ? '&errorMessage=' + errorMessage : ''
#         var img = document.createElement("img");
#         img.width = 1;
#         img.height = 1;
#         img.src = imgUrl
#         document.addEventListener("DOMContentLoaded", function() {
#             var target = data.target || document.body;
#             target.appendChild(img);
#         })
#     } catch (e) {
#         console.log("_ehsTracking:", e)
#     }
# }
#   </script>
#   <script id="ga-ref.js" type="text/javascript">
#    (function (i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#         (i[r].q = i[r].q || []).push(arguments)
#     }, i[r].l = 1 * new Date(); a = s.createElement(o),
#     m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
# ga('create', 'UA-36865869-1', 'auto', {
#     'userId': window._cookie('tracingCode') || '',
# });
# ga('create', 'UA-175542584-1', 'auto', {
#     'name': 'server',
#     'allowLinker': true,
#     'userId': window._cookie('tracingCode') || ''
# });
# ga("require", "ec");
# if (window._cookie('ETMall.FBSigninReturn')) {
#     window._cookie('ETMall.CurrentReferrer') && ga('set', 'referrer', window._cookie('ETMall.CurrentReferrer'));
#     window._cookie('ETMall.FBSigninReturn', '', { path: '/', expires: -200 });
# } else if (document.referrer && document.referrer.indexOf('//www.etmall.com.tw') == -1) {
#     window._cookie('ETMall.CurrentReferrer', document.referrer, { path: "/" });
# }
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-36865869-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#     gtag('config', 'UA-36865869-1', { 'send_page_view': false, 'optimize_id': 'GTM-WCNX4VB' });
#   </script>
#   <!-- Anti-flicker snippet (recommended)  -->
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'optimize-loading','dataLayer',5000,
# {'GTM-WCNX4VB':true});
#   </script>
#   <script id="TrackingFB" type="text/javascript">
#    !function (f, b, e, v, n, t, s) {
#     if (f.fbq) return; n = f.fbq = function () {
#         n.callMethod ?
#         n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#     }; if (!f._fbq) f._fbq = n;
#     n.push = n; n.loaded = !0; n.version = '2.0'; n.queue = []; t = b.createElement(e); t.async = !0;
#     t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)
# }(window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#
#         fbq('init', '763918367495224');
#
# fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src=" https://www.facebook.com/tr?id=763918367495224&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </head>
#  <body class="n-theme--gr2-lighter">
#   <main class="n-wrapper">
#    <header class="n-header n-inside--head">
#     <div class="n-top__ad" id="TopBanner">
#      <div class="n-pic n-skeleton__bg" style="width:100%;height:65px">
#      </div>
#     </div>
#     <div class="n-header__top">
#      <div class="n-layout--lg">
#       <div id="ShortcutLeftData">
#        <ul class="n-left">
#         <li>
#          <a class="sendGA" data-action="All_TopLeft_首頁" data-category="All_TopLeft" data-label="All_TopLeft_首頁" href="/">
#           首頁
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div id="logon">
#        <ul class="n-right">
#         <li>
#          <a class="sendGA" href="/Welfare" rel="nofollow">
#           超級福利社
#          </a>
#         </li>
#         <li class="n-has--drop">
#          <a href="" title="禮物卡">
#           禮物卡
#          </a>
#         </li>
#         <li class="n-has--drop">
#          <a href="javascript:;" title="會員服務">
#           會員服務
#          </a>
#         </li>
#         <li>
#          <a href="/member/wishlist" rel="nofollow" title="收藏">
#           <i class="n-icon--collect">
#           </i>
#           <span>
#            收藏
#           </span>
#          </a>
#         </li>
#         <li class="n-header__cart">
#          <a href="/Order/Basket" rel="nofollow" title="購物車">
#           <i class="n-icon--cart">
#           </i>
#           <span class="count--round n-is--hide fun-shoppingBagIcon-count">
#            <span>
#             0
#            </span>
#           </span>
#           <span>
#            購物車(
#           </span>
#           <span>
#            0
#           </span>
#           <span>
#            )
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="n-header__body">
#      <div class="n-layout--lg fun-Header-FestivalBg">
#       <div class="n-left">
#        <a class="n-ehs--logo sendGA fun-Header-Logo" data-action="Web_All_Logo" data-category="Web_All_Logo" data-label="Web_All_Logo" href="/" title="ETMall東森購物">
#         ETMall東森購物
#        </a>
#       </div>
#       <div id="SearchBar">
#        <div class="n-search__wrap">
#        </div>
#        <div id="SearchKeyWordData">
#         <ul class="n-search__hotkey fun-keyword-lists">
#          <li>
#           熱搜：
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="n-nav__wrap">
#      <div class="n-layout--lg">
#       <nav class="n-nav__box n-left n-nav--hover">
#        <div class="n-title--16">
#         全站商品分類
#         <i class="n-icon--menu n-right">
#         </i>
#        </div>
#        <div id="dropMenu">
#         <ul class="n-nav__list" id="mainNav">
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            <p class="n-skeleton__bg" style="width:50%;">
#            </p>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </nav>
#       <div id="SpecialStore">
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="FiveBanner" id="FiveBanner">
#     <div class="n-banner" id="mainBanner">
#      <div class="EUCarousel-carousel" style="max-width: 100%; min-height: 300px;">
#       <div>
#        <div class="n-banner__wrap">
#         <div class="EUCarousel-fade EUCarousel-carouselShow">
#          <div class="n-layout--lg">
#           <div class="n-banner__box" style="width: 800px; height: 300px; background-position:350px 60px">
#           </div>
#           <div class="n-banner--theme">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="n-layout--lg">
#       <aside class="n-layout--aside n-mem-info">
#        <div class="n-mem-info__wrap">
#         <div class="n-mem-info__login">
#          <div class="n-mem-info__box">
#           <div class="n-mem-info__title">
#            Hi 您好！
#            <br/>
#            立即享受優惠購物
#           </div>
#           <div class="n-mem-info__btns">
#            <a class="n-btn n-btn--primary" href="/Login" style="width: 94px;margin-right:6px;" title="登入">
#             登入
#            </a>
#            <a class="n-btn n-btn--normal" href="/Register" style="width: 94px;" title="註冊">
#             註冊
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="n-mem-info__ad">
#          <div>
#           <div class="n-pic n-skeleton__bg" style="width:180px;height:180px">
#           </div>
#          </div>
#         </div>
#        </div>
#       </aside>
#      </div>
#     </div>
#    </div>
#    <div class="n-layout--lg">
#     <div class="n-l-1015 n-m-bottom--sm n-m-top--sm n-daily-film-today" id="homed">
#      <section class="HomeDailySale" id="HomeDailySale">
#       <ul class="n-daily__head">
#        <li class="n-daily__title n-title--26">
#         限時瘋搶
#         <img src="/Resource/Svg/Activity-hourSale-thunder.svg"/>
#        </li>
#        <li class="n-daily__counter">
#         <div class="n-count__clock p-left-xxl">
#          <span class="n-sp--time">
#           --
#          </span>
#          <span>
#           :
#          </span>
#          <span class="n-sp--time">
#           --
#          </span>
#          <span>
#           :
#          </span>
#          <span class="n-sp--time">
#           --
#          </span>
#         </div>
#        </li>
#        <li class="n-daily__session">
#         <div class="n-skeleton__bg" style="width:68px; height: 30px; border-radius: 3rem; margin: 0 5px;">
#         </div>
#         <div class="n-skeleton__bg" style="width:68px; height: 30px; border-radius: 3rem; margin: 0 5px;">
#         </div>
#         <div class="n-skeleton__bg" style="width:68px; height: 30px; border-radius: 3rem; margin: 0 5px;">
#         </div>
#        </li>
#        <li class="n-daily__more">
#         <a href="/Activity/HourSale" title="看更多">
#          看更多
#         </a>
#        </li>
#       </ul>
#       <div class="n-daily__product-wrap">
#        <div class="n-daily__product-list">
#         <ul class="n-daily__carousel">
#          <li class="n-daily__product-col">
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#          </li>
#          <li class="n-daily__product-col">
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#          </li>
#          <li class="n-daily__product-col">
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#           <a class="n-daily__product-item" href="/Activity/HourSale">
#            <div class="n-daily__pic n-skeleton__bg">
#            </div>
#            <div class="n-daily__product-info">
#             <p class="n-daily__product-name n-skeleton__bg">
#             </p>
#             <div>
#              <p class="n-skeleton__bg">
#              </p>
#             </div>
#             <p class="n-daily__status-wrap n-skeleton__bg">
#             </p>
#            </div>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </section>
#      <div class="HomeMediaSale n-right" id="HomeMediaSale">
#       <div class="n-left n-film" id="LiveVideo">
#        <section class="n-film__wrap">
#         <div class="n-title__wrap">
#          <div class="n-title--16 n-left">
#           <i class="n-icon--video">
#           </i>
#           影音專區
#           <a class="n-film__menu n-right" href="/TVList">
#            節目表
#           </a>
#          </div>
#         </div>
#         <ul class="n-tab__nav n-skeleton__bg">
#         </ul>
#         <div class="n-film__box" id="m_film_wrap">
#          <div class="n-film__video n-skeleton__bg" id="n-film" style="height:115px;">
#          </div>
#          <div class="n-film__product">
#           <p class="n-name n-skeleton__bg n-skeleton-xs margin-xs">
#           </p>
#           <div class="n-skeleton__bg n-skeleton-md margin-xs">
#           </div>
#          </div>
#         </div>
#        </section>
#       </div>
#      </div>
#      <div class="HomeTodayDiscountSale n-right" id="HomeTodayDiscountSale">
#       <div class="n-left n-today">
#        <section class="n-today__wrap">
#         <div class="n-title__wrap">
#          <div class="n-title--16">
#           <i class="n-icon--discount-today">
#           </i>
#           今日特價
#          </div>
#         </div>
#         <figure class="n-product_wrap n-bg--gr2-dp-light">
#          <a class="n-left" href="">
#           <div class="n-pic n-left">
#           </div>
#           <figcaption class="n-price__wrap n-left">
#            <p class="n-name n-skeleton__bg">
#            </p>
#            <div class="n-price__wrap n-left n-skeleton__bg">
#            </div>
#           </figcaption>
#          </a>
#         </figure>
#        </section>
#       </div>
#      </div>
#     </div>
#     <div class="HomeHotActivity" id="HomeHotActivity">
#      <section class="n-hot__wrap n-m-bottom--sm">
#       <div class="n-title__wrap">
#        <div class="n-title--16 n-left">
#         <i class="n-icon--hot-activity">
#         </i>
#         熱門活動
#        </div>
#       </div>
#       <div class="n-hot-banner__wrap">
#        <div class="n-hot-banner__list">
#         <ul class="n-clearfix">
#          <li class="n-skeleton__bg m-left-md" style="height:140px;width:320px;">
#          </li>
#          <li class="n-skeleton__bg m-left-md" style="height:140px;width:320px;">
#          </li>
#          <li class="n-skeleton__bg m-left-md" style="height:140px;width:320px;">
#          </li>
#          <li class="n-skeleton__bg m-left-md" style="height:140px;width:320px;">
#          </li>
#         </ul>
#        </div>
#       </div>
#      </section>
#     </div>
#     <div class="HomePromo" id="HomePromo">
#     </div>
#    </div>
#    <div id="PushNotificationHome">
#    </div>
#    <div id="PushNotificationMarquee">
#    </div>
#    <footer class="n-footer">
#     <div class="n-layout--full n-footer__head">
#      <a class="sendGA" data-action="All_Footer_GoToTop" data-category="All_Footer" data-label="All_Footer_GoToTop" href="#" id="footGoTop" title="TOP">
#       TOP
#      </a>
#     </div>
#     <div class="n-layout--full n-footer__body">
#      <div class="n-layout--md" id="footerJson">
#      </div>
#      <div class="n-layout--md">
#       <div class="n-left n-footer__logo">
#        <a class="sendGA" data-action="All_Footer_Logo" data-category="All_Footer" data-label="All_Footer_Logo" href="/" title="ETMall東森購物">
#        </a>
#       </div>
#       <div class="n-left">
#        <p>
#         本網站所有內容及圖片均不得以任何型式，予以重製或傳送
#         <br/>
#         <a href="/HelpCenter/StandardSecurity" target="_blank" title="安全機制">
#          安全機制
#         </a>
#         與
#         <a href="/HelpCenter/PrivacyStatement" target="_blank" title="隱私聲明">
#          隱私聲明
#         </a>
#         (
#         <a href="/HelpCenter/PCITLS" target="_blank">
#          即日起停用支援TLS 1.0 加密協定
#         </a>
#         )
#         <br/>
#         東森得易購股份有限公司版權所有 台灣 新北市中和區景平路258號1樓
#         <br/>
#         代表人：王令麟
#         <br/>
#         24H 免費服務專線：
#         <a class="sendGA" data-action="All_Footer_Call0800" data-category="All_Footer" data-label="All_Footer_Call0800" href="tel:0800-057-999" target="_blank" title="24H 免費服務專線：0800-057-999">
#          0800-057-999
#         </a>
#         <br/>
#         電子信箱：
#         <a href="mailto:ehs_service@ehsn.com.tw" title="電子信箱：ehs_service@ehsn.com.tw">
#          ehs_service@ehsn.com.tw
#         </a>
#         <br/>
#         2019 EASTERN HOME SHOPPING &amp; LEISURE CO., LTD. All Rights Reserved.
#        </p>
#       </div>
#       <div class="n-right n-text--center">
#        <div class="d-inline-block align-top m-right-xxl">
#         <div class="SMALL" id="twcaseal">
#          <img src="/Resource/Images/TWCA_SMALL_SIZE.gif?v1"/>
#         </div>
#         <script charset="utf-8" type="text/javascript">
#          var twca_cn="www.etmall.com.tw";
#         </script>
#         <script charset="utf-8" src="//ssllogo.twca.com.tw/twcaseal_v3.js" type="text/javascript">
#         </script>
#        </div>
#        <div class="d-inline-block">
#         <img alt="資訊安全管理系統認證" src="/Resource/Images/BSI_Assurance_Mark_ISO_27001_Black.png?v3" style="margin-bottom: 5px; width: 120px;"/>
#         <p>
#          資訊安全管理
#          <br/>
#          系統認證
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#    <a class="n-gotop" href="#" id="goTop" style="opacity: 0;" title="Go Top">
#     <span>
#     </span>
#     <span>
#     </span>
#     <span>
#     </span>
#    </a>
#    <div id="Dialog">
#    </div>
#    <div id="Modal">
#    </div>
#    <div id="CrazyAdBlock">
#    </div>
#    <div id="ProductDetailBlock">
#     <div id="ProductDetailMainBlock">
#     </div>
#     <div id="ProductDetailIntroBlock">
#     </div>
#    </div>
#    <div id="Popup">
#    </div>
#    <div id="AutoComplete">
#    </div>
#    <div id="PushNotification">
#    </div>
#    <div class="n-cover__wrap" id="coverBgWrap">
#     <a class="n-cover--bg-l" title="supper ad">
#     </a>
#     <a class="n-cover--bg-r" title="supper ad">
#     </a>
#    </div>
#    <div id="Popup">
#    </div>
#   </main>
#   <div id="fb-root">
#   </div>
#   <script>
#    document.addEventListener('DOMContentLoaded', function(){
#     (function (d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.async = true;
#         js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.7&appId=289388427741701";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
# });
#   </script>
#   <script src="/Resource/Bundle/Vendor.js?v=097ae746b250c1a548d1">
#   </script>
#   <script src="/Resource/Bundle/Runtime.js?v=5297d99a77fdbf903e2f">
#   </script>
#   <script src="/Resource/Bundle/Commons.js?v=b50d0629445ea8aa9b7f">
#   </script>
#   <script src="/Resource/Bundle/Home.js?v=df6435918c695e91e5d1">
#   </script>
#   <script>
#    ReactDOM.render(React.createElement(Components.PushNotification, {"marqueeData":[{"GoodID":2457618,"Time":"13:52","Name":"【福利品 】Apple iPhone 8 Plus 256GB","Link":"/i/2457618","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2448053,"Time":"13:52","Name":"任天堂Switch主機(續航加強版)+健身環大冒險(台灣公司貨中文版)《贈：玻璃保護貼+手把果凍套含類比組》","Link":"/i/2448053","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2917819,"Time":"13:52","Name":"BESO 軟Q輕彈健步鞋(好運滿滿發財價)-ESV-裸","Link":"/i/2917819","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2704921,"Time":"13:52","Name":"realme X3 S855+四鏡頭全速旗艦機(8G+128G)-極地白","Link":"/i/2704921","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2907340,"Time":"13:52","Name":"十級濾心(4入組)","Link":"/i/2907340","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2433225,"Time":"13:52","Name":"MyCard 50點 點數卡","Link":"/i/2433225","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2593884,"Time":"13:52","Name":"WEISHTON女抗皺襯衫長袖，素色白，斜紋白，斜紋藍","Link":"/i/2593884","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2891121,"Time":"13:52","Name":"BIKEONE L6 LITE 20寸單速簡約且易於操控的城市自行車淑女車，好騎乘，符合人體工程學專為在城市自由騎行而設計","Link":"/i/2891121","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2758668,"Time":"13:52","Name":"德國304不鏽鋼蜂巢不沾大炒鍋34公分附可立玻璃蓋","Link":"/i/2758668","CreateDate":"0001-01-01T00:00:00"},{"GoodID":2912074,"Time":"13:52","Name":"衛元堂百草十八味清廢茶迎春組-勁-春","Link":"/i/2912074","CreateDate":"0001-01-01T00:00:00"}],"marquee":true,"isOpenPushNotification":true,"isOpenMarquee":true}), document.getElementById("PushNotificationMarquee"));
# ReactDOM.render(React.createElement(Components.PushNotification, {"pushURL":"/Home/GetMobilePushAD","onlyShowOnce":true,"showTime":8000,"redirectURL":"/","isOpenPushNotification":true,"isOpenMarquee":true,"isUseServiceWorker":true,"gaWebTrackingID":"UA-36865869-1","config":{"apiKey":"AIzaSyBy1BUg_wA5QaAdCqcL4IDhZb_o312C3Ug","authDomain":"noted-strength-87202.firebaseapp.com","databaseURL":"https://noted-strength-87202.firebaseio.com","projectId":"noted-strength-87202","storageBucket":"","messagingSenderId":"143509994561"}}), document.getElementById("PushNotification"));
#   </script>
#   <script type="text/javascript">
#    var CrazyAD = [{"Name":"0214家電","StoreID":"etmallcrazyad","DateGA":"20210214","Link":"https://www.etmall.com.tw/XML/content/DMSetting/Final/202102/SP_1116935/index.html","LinkClick":"https://media.etmall.com.tw/sp/7544/m/index.html"}];
#     if(CrazyAD.length){
#         ReactDOM.render(React.createElement(Components.CrazyAd ,{
#             data: CrazyAD,
#         }), document.getElementById("CrazyAdBlock"));
#     }
#     ReactDOM.render(React.createElement(Components.TopBannerData, {
#         data: [{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/189227/20566fff-6c2f-4145-ba48-3daf8c3a4f38.jpg","Link":"https://www.etmall.com.tw/XML/content/DMSetting/Final/202101/SP_1116904/w/index.html","Alt":"東森大樂透"},{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/188800/e6f4cdfb-c0f0-4d81-830a-66f2930b46db.jpg","Link":"https://media.etmall.com.tw/sp/8143/m/index.html","Alt":"過年不出貨公告"},{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/190706/849bf941-7824-426e-8723-1808fac61798.jpg","Link":"https://www.etmall.com.tw/p/123447","Alt":"0214保健"},{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/190707/51c5756b-a6c6-49a8-b1bf-13ea7b23d78e.jpg","Link":"https://www.etmall.com.tw/p/119577","Alt":"0214美食"},{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/190708/b6f4f6fe-d0a2-4af8-9aa8-45e70dde7ae3.jpg","Link":"https://media.etmall.com.tw/sp/8212/m/index.html","Alt":"0214資訊"},{"Image":"//media.etmall.com.tw/Promo/Image/Kanban/6/190709/2d1439df-75e1-4cf1-a01b-8b2381eac859.jpg","Link":"https://www.etmall.com.tw/gp/108346","Alt":"0214華陀"}],
#     }), document.getElementById("TopBanner"));
#
#     ReactDOM.render(React.createElement(Components.ShortcutLeftData, {
#         data: [{"Title":"首頁","Link":"https://www.etmall.com.tw"},{"Title":"直配大陸","Link":"https://www.etmall.com.tw/s/22223"},{"Title":"環保綠點","Link":"https://www.etmall.com.tw/product/greenpointsp"},{"Title":"票券兌點","Link":"https://www.etmall.com.tw/member/MExchangeECoin"}],
#         mobileDomain: "//m.etmall.com.tw"
#     }), document.getElementById("ShortcutLeftData"));
#
#     ReactDOM.render(React.createElement(Components.SearchBar, {
#         data: [{"Word":"保暖塑身","Url":null},{"Word":"年菜","Url":null},{"Word":"S21","Url":null},{"Word":"吸塵器","Url":null},{"Word":"床墊","Url":null},{"Word":"泡湯券","Url":null},{"Word":"櫃子","Url":null},{"Word":"realme X3","Url":null},{"Word":"除濕機","Url":null},{"Word":"LV","Url":null},{"Word":"COACH包","Url":null},{"Word":"中衛","Url":null},{"Word":"PS5 主機","Url":null},{"Word":"csd","Url":null},{"Word":"曼黛瑪璉","Url":null},{"Word":"switch","Url":null},{"Word":"中衛口罩","Url":null},{"Word":"除濕機","Url":null},{"Word":"mycard","Url":null},{"Word":"airpods","Url":null},{"Word":"中衛醫療口罩","Url":null},{"Word":"台酒生技","Url":null},{"Word":"氣炸鍋","Url":null},{"Word":"switch主機","Url":null},{"Word":"大同電鍋","Url":null},{"Word":"東森網路購物","Url":null},{"Word":"ysl包包","Url":null},{"Word":"ps5預購","Url":null},{"Word":"鍋寶","Url":null},{"Word":"安博盒子","Url":null},{"Word":"csd 中衛口罩","Url":null}],
7cETMall%e6%9d%b1%e6%a3%ae%e8%b3%bc%e7%89%a9"},{"Title":"國際美妝","Image":"//media.etmall.com.tw/Promo/Image/Kanban/7/190264/218cf91f-70cc-429f-817c-311202ac8954.png","Link":"https://media.etmall.com.tw/sp/8318/m/index.html","MobileImage":"//media.etmall.com.tw/Promo/Image/Kanban/7/190264/8d378f76-4841-4901-b872-d7e506a71086.png","MobileLink":"https://media.etmall.com.tw/sp/8318/m/index.html","AppLink":"etmall://open?pgid=44&url=https%3a%2f%2fmedia.etmall.com.tw%2fsp%2f8318%2fm%2fapp.html&t=%e6%84%9b%e4%bd%a0%e6%b2%92%e6%8a%98%e4%b8%8b%e5%96%ae%e6%9c%89%e6%8a%98%7cETMall%e6%9d%b1%e6%a3%ae%e8%b3%bc%e7%89%a9"},{"Title":"登記送禮","Image":"//media.etmall.com.tw/Promo/Image/Kanban/7/189957/e414d728-0b40-44a6-906e-1eb88a2bd118.png","Link":"https://www.etmall.com.tw/gp/124141","MobileImage":"//media.etmall.com.tw/Promo/Image/Kanban/7/189957/7126485e-9ca4-4582-bad2 ...
#         layoutHome: true
#     }), document.getElementById("SpecialStore"));
#
#     ReactDOM.render(React.createElement(Components.DropMenu, {
#         CategoriesTree: [{"Category":{"CateID":8505,"CateName":"品牌旗艦","IsLastLevel":false,"DefaultUrl":"/","IsCurrentCate":false,"HighlightType":0},"SubCategories":[{"Category":{"CateID":142808,"CateName":"數位轉型專案","IsLastLevel":false,"DefaultUrl":"/數位轉型專案/c1/142808","IsCurrentCate":false,"HighlightType":0},"SubCategories":[{"Category":{"CateID":147865,"CateName":"彰化購物專區","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/147866","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":142816,"CateName":"經濟部推動專案","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/142823","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null}],"Logo":null},{"Category":{"CateID":53196,"CateName":"3C／家電","IsLastLevel":false,"DefaultUrl":"/3C-家電/c1/53196","IsCurrentCate":false,"HighlightType":0},"SubCategories":[{"Category":{"CateID":53197,"CateName":"ASUS華碩","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/53235","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":53198,"CateName":"ACER宏碁","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/53236","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":113232,"CateName":"dyson戴森","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/55179","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":113237,"CateName":"LG","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/113224","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":113231,"CateName":"Panasonic國際牌","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/113225","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":113236,"CateName":"PHILIPS飛利浦","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/113223","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":120008,"CateName":"SHARP夏普","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/119162","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":112772,"CateName":"TIGER虎牌","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/97324","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":112773,"CateName":"日本象印","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/102524","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":134148,"CateName":"3M","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/113204","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":135303,"CateName":"鍋寶","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/53340","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":144071,"CateName":"HITACHI日立","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/144108","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":148693,"CateName":"正負零±0","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/148692","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null}],"Logo":null},{"Category":{"CateID":53206,"CateName":"生活／婦幼","IsLastLevel":false,"DefaultUrl":"/生活-婦幼/c1/53206","IsCurrentCate":false,"HighlightType":0},"SubCategories":[{"Category":{"CateID":53208,"CateName":"3M","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/113204","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":53210,"CateName":"H＆D","IsLastLevel":true,"DefaultUrl":"https://www.etmall.com.tw/bs/53215","IsCurrentCate":false,"HighlightType":0},"SubCategories":null,"Logo":null},{"Category":{"CateID":53207,"CateName":"LooCa","IsLa ...
#         Festival: [{"leftBg":"//media.etmall.com.tw/Promo/Image/Kanban/9/190724/c974062b-f167-46c6-aec8-0ba9e972dd33.jpg","leftLink":"https://www.etmall.com.tw/gp/123664","rightBg":"//media.etmall.com.tw/Promo/Image/Kanban/9/190724/568a1285-d572-4644-a587-d7a59b7efa87.jpg","rightLink":"https://www.etmall.com.tw/gp/123664","logo":null,"headerBg":null,"title":"蠶絲美體衣$888"}],
#         layoutHome: true,
#     }), document.getElementById("dropMenu"));
#
},{"Name":"葉黃素","Url":"https://www.etmall.com.tw/亮亮晶明-機能保健/c2/29298"},{"Name":"小農","Url":"https://www.etmall.com.tw/產銷履歷專區-生鮮-水果/c3/115544"},{"Name":"水果","Url":"https://www.etmall.com.tw/產地直送專區-生鮮-水果/c3/115545"},{"Name":"蔬菜","Url":"https://www.etmall.com.tw/蔬菜-生鮮-水果/c2/41471"},{"Name":"按摩","Url":"https://www.etmall.com.tw/按摩家電/c1/103120"},{"Name":"跑步機","Url":"https://www.etmall.com.tw/跑步-健走-滑步機-樂活健身/c3/103769"},{"Name":"益生菌","Url":"https://www.etmall.com.tw/益生菌-嗯嗯好順暢/c3/29248"},{"Name":"膠原蛋白","Url":"https://www.etmall.com.tw/膠原蛋白-彈力美肌/c3/29079"},{"Name":"白黎蘆醇","Url":"https://www.etmall.com.tw/白黎蘆醇-逆齡對策/c3/29111"},{"Name":"咖啡","Url":"https://www.etmall.com.tw/沖泡飲品/c1/27045"},{"Name":"茶葉","Url":"https://www.etmall.com.tw/茶葉-茶包/c1/26982"},{"Name":"孕媽咪","Url":"https://www.etmall.com.tw/topic/孕產婦用品"}]},{"Name":"專題-時尚穿搭","Url":"","Image":"https://media.etmall.com.tw/Promo/Image/TopicImg/20180206/20180206123250552_.jpg","Keyword":[{"Name":"內搭褲","Url":"https://www.etmall.com.tw/內搭褲-裙-褲/c3/27116"},{"Name":"洋裝","Url":"https://www.etmall.com.tw/洋裝-套裝-女裝/c2/16422"},{"Name":"春夏新裝","Url":"https://www.etmall.com.tw/女裝/c1/16421"},{"Name":"秋冬出清","Url":"https://www.etmall.com.tw/外套-大衣-女裝/c2/19511"},{"Name":"穿搭配件","Url":"https://www.etmall.com.tw/穿搭配飾/c1/15802"},{"Name":"無鋼圈胸罩","Url":"https://www.etmall.com.tw/女生內衣-女生內衣褲/c2/28199"},{"Name":"外套","Url":"https://www.etmall.com.tw/外套-大衣-女裝/c2/19511"},{"Name":"手錶","Url":"https://www.etmall.com.tw/專櫃精品錶/c1/38979"},{"Name":"背包","Url":"https://www.etmall.com.tw/背包-女包/c2/94416"},{"Name":"皮夾","Url":"https://www.etmall.com.tw/皮夾款式-女包/c2/45727"},{"Name":"羽絨外套","Url":"https://www.etmall.com.tw/羽絨外套-外套-大衣/c3/27135"}]},{"Name":"專題-發燒品牌","Url":"","Image":"ht ...
#         isBigData: true,
#         isFullVersionLayout: true
#     }), document.getElementById("HomePromo"));
#
#     ReactDOM.render(React.createElement(Components.PushNotification, {
#         isUseServiceWorker: true,
#         forceUpdateServiceWorker: false,
#         gaWebTrackingID: "UA-36865869-1",
#         gaMobileTrackingID: "",
#         config: {"apiKey":"AIzaSyBy1BUg_wA5QaAdCqcL4IDhZb_o312C3Ug","authDomain":"noted-strength-87202.firebaseapp.com","databaseURL":"https://noted-strength-87202.firebaseio.com","projectId":"noted-strength-87202","storageBucket":"","messagingSenderId":"143509994561"}
#     }), document.getElementById("PushNotificationHome"));
#   </script>
#   <!--Scripts for all ADS start-->
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N8MKXWM" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script id="TrackingGAClick">
#    (function () {
# 	if (typeof ga == 'undefined' || typeof $.fn.sendGaTracking == 'undefined') return;
# 	function sendGA(that) {
# 		var target = $(that),
# 			link = target.attr('href') || '',
# 			dataLink = target.data('link') || '',
# 			trackingInfo = {
# 				category: target.attr('data-category'),
# 				action: target.attr('data-action'),
#                 label: target.attr('data-label'),
#             };
#
#         // for "DCS" custom event use
#         var DcsEvent = target.attr('data-dcs')
#             ? JSON.parse(target.attr('data-dcs'))
#             : null
#
#         $.fn.sendGaTracking(trackingInfo, link, false, {
#             DcsEvent: DcsEvent
#         });
#         if (target.data('category') && target.data('category').indexOf("FBLogin") > -1) {
#             document.referrer && window._cookie('ETMall.FBSigninReturn', true, { path: "/" });
#         }
#
#         var SCUPIO_LINK_GA_COOKIE = link.indexOf("/RecWeb/") > -1 || dataLink.indexOf("/RecWeb/") > -1
#         var LINK_GA_COOKIE = link.indexOf("/i/") > -1 || dataLink.indexOf("/i/") > -1
#
#         if (SCUPIO_LINK_GA_COOKIE || LINK_GA_COOKIE) {
# 			$.fn.setGACodeCookie(trackingInfo.label);
# 		}
# 	}
#     $(document).ready(function () {
#         $(document).on('click', '.sendGA', function (event) {
#             utilityJS.cancelBubble(event);
# 			sendGA(this);
# 		})
#         $(document).on('click', '.sendGAWithoutCancelBubble', function () {
#             sendGA(this)
#         })
#     });
#     //for safari and firefox back forward cache
#     window.onpageshow = function (event) {
#         if (event.persisted) {
#             window.location.reload()
#         }
#     };
# })();
#   </script>
#   <script>
#    //gtag for page performace time
#     $(window).load(function(){
#         if (gtag && window.performance) {
#             var timeSincePageLoad = Math.round(performance.now());
#             gtag('event', 'timing_complete', {
#                 'name': 'load',
#                 'value': timeSincePageLoad,
#                 'event_category': 'Home_Index',
#                 'event_label': 'Index'
#             });
#         }
#     })
#   </script>
#   <script>
#    try {
#             (function (w, d, t, r, u) { var f, n, i; w[u] = w[u] || [], f = function () { var o = { ti: '4015335' }; o.q = w[u], w[u] = new UET(o), w[u].push("pageLoad") }, n = d.createElement(t), n.src = r, n.async = 1, n.onload = n.onreadystatechange = function () { var s = this.readyState; s && s !== "loaded" && s !== "complete" || (f(), n.onload = n.onreadystatechange = null) }, i = d.getElementsByTagName(t)[0], i.parentNode.insertBefore(n, i) })(window, document, "script", "//bat.bing.com/bat.js", "uetq");
#         } catch (e) {
#             console.log(e)
#         }
#   </script>
#   <script type="application/javascript">
#    (function(w,d,t,r,u){w[u]=w[u]||[];w[u].push({'projectId':'10000','properties':{'pixelId':'436676'}});var s=d.createElement(t);s.src=r;s.async=true;s.onload=s.onreadystatechange=function(){var y,rs=this.readyState,c=w[u];if(rs&&rs!="complete"&&rs!="loaded"){return}try{y=YAHOO.ywa.I13N.fireBeacon;w[u]=[];w[u].push=function(p){y([p])};y(c)}catch(e){}};var scr=d.getElementsByTagName(t)[0],par=scr.parentNode;par.insertBefore(s,scr)})(window,document,"script","https://s.yimg.com/wi/ytc.js","dotq");
#
#         /* 有共用且最下層的 JSX 元件會取用 app.config 上的 YAHOO_NATIVE_ID, 故將其扔給全域供取用。 */
#         this.YAHOO_NATIVE_ID ='436676';
#   </script>
#   <script async="" src="//rec.scupio.com/recweb/js/rec.js">
#   </script>
#   <script async="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript">
#   </script>
#   <script>
#    try {
#             (function () {
#                 window.criteo_q = window.criteo_q || [];
#                 window.criteo_q.push(
#                     { event: 'setAccount', account: 27373 },
#                     { event: 'setSiteType', type: (utilityJS.isIPad() ? 't' : (utilityJS.isMobile() ? 'm' : 'd')) },
#                     { event: 'viewHome' }
#                 );
#             }());
#         } catch (error) {
#             console.log("Home_Criteo", error)
#         }
#   </script>
#   ﻿
#   <script id="TrackingDMP" type="text/javascript">
#    var _dcsScript = document.createElement('script');
#     _dcsScript.type = 'text/javascript';
#     _dcsScript.async = true;
#     _dcsScript.src = 'https://dcs.ettoday.net/api/dcs-client.js'
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(_dcsScript, s);
#
#     var _dcsClient = {
#         feed: 'etmall',
#         api: null,
#         event: {
#             'event_type': 'page',
#             'page': {
#                 'title': document.title,
#                 'uri': window.location.href,
#                 'referrer_uri': document.referrer,
#                 'hostname': window.location.hostname
#             },
#             'cookie_mapping': {
#                 'etu_eruid': null
#             },
#             'app': {
#                 'type': 'web'
#             }
#         },
#         Fingerprint2: new Fingerprint2()
#     }
#     // 取得登入ID
#     var isUserLogined = window._cookie('tracingCode') || ''
#     if(isUserLogined){
#         _dcsClient.event['user'] = { 'id': isUserLogined }
#     }
#   </script>
#   <script>
#    try {
#             function dcsClientReady(dcsClientApi) {
#                 _dcsClient.api = dcsClientApi;
#                 _dcsClient.Fingerprint2.get(function (fingerprint) {
#                     _dcsClient.event.page['type'] = 'home';
#                     _dcsClient.event.app['browser_fingerprint'] = fingerprint
#                     _dcsClient.api.push(_dcsClient.feed, _dcsClient.event);
#                 })
#             }
#         } catch (error) {
#             console.log("Home_DCS", error)
#         }
#   </script>
#   <script>
#    try {
#             (window._bwtm = window._bwtm || []).push({
#                 "mid": 64,
#                 "ch": "",
#                 "pid": "home",
#                 "uid": utilityJS.cookie('tracingCode') ? utilityJS.cookie('tracingCode') : ""
#             });
#         } catch (error) {
#             console.log("Order3_Scupio", error)
#         }
#   </script>
#   <script type="text/javascript">
#    (function () {
#     if (typeof ga == 'undefined' || new URLSearchParams(window.location.search).get('keyword') || window.location.href.includes('/i/')) return;
#     ga('send', 'pageview');
#     ga('server.send', 'pageview');
# })();
#   </script>
#   <!--Scripts for all ADS end-->
#   <script>
#    var isAlreadyShowNotSupportIE9 = sessionStorage.getItem("ETMall.alreadyShowNotSupportIE9")
#     var isNotShowAgainIn1Day = utilityJS.cookie('ETMall.NotShowAgainIn1Day')
#
#     if (utilityJS.isIE9()) {
#         if (isAlreadyShowNotSupportIE9 !== 'true' || isNotShowAgainIn1Day !== 'true') {
#             Components.Modal.alert('請使用 Internet Explorer 10以上版本，建議您更新版本，以獲得最佳瀏覽體驗。')
#
#             sessionStorage.setItem("ETMall.alreadyShowNotSupportIE9", 'true')
#             window._cookie('ETMall.NotShowAgainIn1Day', true, {
#                 path: '/',
#                 expires: 1
#             })
#         }
#     }
#   </script>
#  </body>
# </html>

# %% [markdown]
# 東森購物24h若無header訊息則無法成功訪問
# 補上user-agent即可
